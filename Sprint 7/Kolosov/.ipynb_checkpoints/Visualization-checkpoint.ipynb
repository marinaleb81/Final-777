# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Загрузка данных
data = pd.read_csv('data_train_proc_FINAL.csv',sep=';')
data.head(10)
# Out:
#    Sum_Parameter  Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  \
# 0              0                    1596         36.1              140
# 1              0                    1759         29.1              200
# 2              0                    1805         26.5               25
# 3              0                    1524         44.3              197
# 4              0                    1641         35.4               34
# 5              0                    1429         42.1               65
# 6              0                    1413         42.9              156
# 7              0                    1609         38.1               67
# 8              0                    1578         35.2               13
# 9              0                    1447         53.3               98
#
#    Air temperature [K]  Process temperature [K]  Machine failure
# 0                300.6                    309.6                0
# ...

# %%
# Построим диаграмму рассеяния:
# По одной оси Sum_Parameter, по другой оси Rotational speed [rpm]

data_not_failure = data.loc[data['Machine failure'] == 0]
data_failure = data.loc[data['Machine failure'] == 1]

sns.countplot(x='Rotational speed [rpm]',data=data,hue='Machine failure')
# Out:
# <Axes: xlabel='Rotational speed [rpm]', ylabel='count'>
